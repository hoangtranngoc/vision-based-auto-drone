# %%
from skimage.io import imread
import numpy as np
import fnmatch
import os
import re
import random
import time

import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import backend as K
from keras.backend.tensorflow_backend import set_session
from keras.utils import Sequence, to_categorical
from keras.layers import Convolution2D, GlobalAveragePooling2D, Activation, Dropout
from keras.models import Model

import sys
if "E:\\git\\keras-squeezenet" not in sys.path:
    sys.path.append("E:\\git\\keras-squeezenet")
    print(sys.path)

import keras_squeezenet.squeezenet
# Out:
# Using TensorFlow backend.
# ['', 'C:\\ProgramData\\Anaconda3\\python36.zip', 'C:\\ProgramData\\Anaconda3\\DLLs', 'C:\\ProgramData\\Anaconda3\\lib', 'C:\\ProgramData\\Anaconda3', 'C:\\Users\\hoang\\AppData\\Roaming\\Python\\Python36\\site-packages', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\hoang\\.ipython', 'E:\\git\\keras-squeezenet']

# %%
#TODO check shuffle
class CustomDataGenerator(Sequence):

    def __init__(self, directory, batch_size, classes):
        self.directory = directory
        self.batch_size = batch_size
        self.classes = classes
        
        #create filenames, labels
        dirs = [d for d in os.listdir(directory) if os.path.isdir(os.path.join(directory, d))]
        print(dirs)
        self.files = []
        for d in dirs:
            fullpath_dir = os.path.join(directory,d)
            new_elements = [(f,d) for f in os.listdir(fullpath_dir)]
            self.files.extend(new_elements)
        
        # shuffle
        random.shuffle(self.files)
        print(len(self.files))
    
    
    def getLabels(self, offsetStr, viewStr, altitudeStr): 
        offset = 0
        view = 0
        altitude = 0
        for i, e in enumerate(self.classes[0]):
            if e == offsetStr:
                offset = i
                break
            
        for i, e in enumerate(self.classes[1]):
            if e == viewStr:
                view = i
                break
        
        for i, e in enumerate(self.classes[2]):
            if e == altitudeStr:
                altitude = i
                break
                
        return offset, view, altitude
    
    
    def __len__(self):
        return int(np.ceil(len(self.files) / float(self.batch_size)))

    def on_epoch_end(self):
        'Shuffle for the next epoch'
        random.shuffle(self.files)
    
    def __getitem__(self, idx):
        batch_x = []
        batch_y1 = []
        batch_y2 = []
        batch_y3 = []
        batch = self.files[idx * self.batch_size : (idx + 1) * self.batch_size]
        #print(self.directory)
        #print ('files from getitem(): ', batch)
        p = re.compile('(left|center|right)Offset_(left|straight|right)View_(low|medium|high)Altitude')
        
        for (file, d) in batch:
            
            finds = p.findall(d)
            #TODO assert only finds has only 1 element [(_,_)]
            (offsetStr, viewStr, altitudeStr) =  finds[0]
            (offset, view, altitude) = self.getLabels(offsetStr, viewStr, altitudeStr)
            
            folder = os.path.join(self.directory, d)
            rgba = imread(os.path.join(folder, file))
            rgb = rgba[:,:,:3]
            
            input_array = rgb / 255.0
            
            batch_x.append(input_array)
            batch_y1.append(offset)
            batch_y2.append(view)
            batch_y3.append(altitude)
         
        return np.array(batch_x), [np.array(to_categorical(batch_y1, 3)), np.array(to_categorical(batch_y2, 3)), np.array(to_categorical(batch_y3, 3))]

# %%
config = tf.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = 0.6
config.gpu_options.allow_growth = True  #dynamically grow the memory used on the GPU
set_session(tf.Session(config=config))

# dimensions of our images.
img_width, img_height = 512, 512

train_data_dir = 'E:\\UAV_drone\\data\\training\\constant_distance_to_lines\\train'
val_data_dir = 'E:\\UAV_drone\\data\\training\\constant_distance_to_lines\\val'
nb_train_samples = 118646
nb_validation_samples = 29802
epochs = 100
batch_size = 32
img_channels = 3
nb_classes = 3

if K.image_data_format() == 'channels_first':
    input_shape = (img_channels, img_width, img_height)
else:
    input_shape = (img_width, img_height, img_channels)

# this is the augmentation configuration we will use for training
classes = [['left', 'center', 'right'], ['left', 'straight', 'right'], ['low', 'medium', 'high']]
train_datagen = CustomDataGenerator(train_data_dir, batch_size, classes)

# this is the augmentation configuration we will use for testing:
val_datagen = CustomDataGenerator(val_data_dir, batch_size, classes)


# checkpoint
current_directory = os.getcwd()
checkpoint_dir = os.path.join(current_directory, 'checkpoints')
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

file="model_squeezenet_view-offset-altitude_{epoch:02d}.hdf5"
checkpoint =  ModelCheckpoint(os.path.join(checkpoint_dir, file), verbose=1)

NAME = "squeezenet_view-offset-altitude_{}".format(int(time.time()))
tensorboard = TensorBoard(log_dir='logs/{}'.format(NAME), write_graph = True, write_images=True)
# Out:
# ['centerOffset_leftView_highAltitude', 'centerOffset_leftView_lowAltitude', 'centerOffset_leftView_mediumAltitude', 'centerOffset_rightView_highAltitude', 'centerOffset_rightView_lowAltitude', 'centerOffset_rightView_mediumAltitude', 'centerOffset_straightView_highAltitude', 'centerOffset_straightView_lowAltitude', 'centerOffset_straightView_mediumAltitude', 'leftOffset_leftView_mediumAltitude', 'leftOffset_rightView_mediumAltitude', 'leftOffset_straightView_highAltitude', 'leftOffset_straightView_lowAltitude', 'leftOffset_straightView_mediumAltitude', 'rightOffset_leftView_mediumAltitude', 'rightOffset_rightView_mediumAltitude', 'rightOffset_straightView_highAltitude', 'rightOffset_straightView_lowAltitude', 'rightOffset_straightView_mediumAltitude']
# 118646
# ['centerOffset_leftView_highAltitude', 'centerOffset_leftView_lowAltitude', 'centerOffset_leftView_mediumAltitude', 'centerOffset_rightView_highAltitude', 'centerOffset_rightView_lowAltitude', 'centerOffset_rightView_mediumAltitude', 'centerOffset_straightView_highAltitude', 'centerOffset_straightView_lowAltitude', 'centerOffset_straightView_mediumAltitude', 'leftOffset_leftView_mediumAltitude', 'leftOffset_rightView_mediumAltitude', 'leftOffset_straightView_highAltitude', 'leftOffset_straightView_lowAltitude', 'leftOffset_straightView_mediumAltitude', 'rightOffset_leftView_mediumAltitude', 'rightOffset_rightView_mediumAltitude', 'rightOffset_straightView_highAltitude', 'rightOffset_straightView_lowAltitude', 'rightOffset_straightView_mediumAltitude']
# 29802

# %%
net = keras_squeezenet.squeezenet.SqueezeNet(include_top=None, input_shape=input_shape, weights=None, classes=nb_classes)
x = net.output

outputs = []
multi_output = 3
for i in range(multi_output):
    drop = Dropout(0.5)(x)

    conv = Convolution2D(nb_classes, (1, 1), padding='valid')(drop)
    relu_conv = Activation('relu')(conv)
    avg = GlobalAveragePooling2D()(relu_conv)
    loss = Activation('softmax')(avg)
    outputs.append(loss)
    
model = Model(net.inputs, outputs=outputs, name='squeezenet')

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 255, 255, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# relu_conv1 (Activation)         (None, 255, 255, 64) 0           conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 127, 127, 64) 0           relu_conv1[0][0]
# __________________________________________________________________________________________________
# fire2/squeeze1x1 (Conv2D)       (None, 127, 127, 16) 1040        pool1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_squeeze1x1 (Activati (None, 127, 127, 16) 0           fire2/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand1x1 (Conv2D)        (None, 127, 127, 64) 1088        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand3x3 (Conv2D)        (None, 127, 127, 64) 9280        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand1x1 (Activatio (None, 127, 127, 64) 0           fire2/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand3x3 (Activatio (None, 127, 127, 64) 0           fire2/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire2/concat (Concatenate)      (None, 127, 127, 128 0           fire2/relu_expand1x1[0][0]
#                                                                  fire2/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/squeeze1x1 (Conv2D)       (None, 127, 127, 16) 2064        fire2/concat[0][0]
# __________________________________________________________________________________________________
# fire3/relu_squeeze1x1 (Activati (None, 127, 127, 16) 0           fire3/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand1x1 (Conv2D)        (None, 127, 127, 64) 1088        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand3x3 (Conv2D)        (None, 127, 127, 64) 9280        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand1x1 (Activatio (None, 127, 127, 64) 0           fire3/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand3x3 (Activatio (None, 127, 127, 64) 0           fire3/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/concat (Concatenate)      (None, 127, 127, 128 0           fire3/relu_expand1x1[0][0]
#                                                                  fire3/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 63, 63, 128)  0           fire3/concat[0][0]
# __________________________________________________________________________________________________
# fire4/squeeze1x1 (Conv2D)       (None, 63, 63, 32)   4128        pool3[0][0]
# __________________________________________________________________________________________________
# fire4/relu_squeeze1x1 (Activati (None, 63, 63, 32)   0           fire4/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand1x1 (Conv2D)        (None, 63, 63, 128)  4224        fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand3x3 (Conv2D)        (None, 63, 63, 128)  36992       fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand1x1 (Activatio (None, 63, 63, 128)  0           fire4/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand3x3 (Activatio (None, 63, 63, 128)  0           fire4/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire4/concat (Concatenate)      (None, 63, 63, 256)  0           fire4/relu_expand1x1[0][0]
#                                                                  fire4/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/squeeze1x1 (Conv2D)       (None, 63, 63, 32)   8224        fire4/concat[0][0]
# __________________________________________________________________________________________________
# fire5/relu_squeeze1x1 (Activati (None, 63, 63, 32)   0           fire5/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand1x1 (Conv2D)        (None, 63, 63, 128)  4224        fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand3x3 (Conv2D)        (None, 63, 63, 128)  36992       fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand1x1 (Activatio (None, 63, 63, 128)  0           fire5/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand3x3 (Activatio (None, 63, 63, 128)  0           fire5/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/concat (Concatenate)      (None, 63, 63, 256)  0           fire5/relu_expand1x1[0][0]
#                                                                  fire5/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool5 (MaxPooling2D)            (None, 31, 31, 256)  0           fire5/concat[0][0]
# __________________________________________________________________________________________________
# fire6/squeeze1x1 (Conv2D)       (None, 31, 31, 48)   12336       pool5[0][0]
# __________________________________________________________________________________________________
# fire6/relu_squeeze1x1 (Activati (None, 31, 31, 48)   0           fire6/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand1x1 (Conv2D)        (None, 31, 31, 192)  9408        fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand3x3 (Conv2D)        (None, 31, 31, 192)  83136       fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand1x1 (Activatio (None, 31, 31, 192)  0           fire6/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand3x3 (Activatio (None, 31, 31, 192)  0           fire6/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire6/concat (Concatenate)      (None, 31, 31, 384)  0           fire6/relu_expand1x1[0][0]
#                                                                  fire6/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/squeeze1x1 (Conv2D)       (None, 31, 31, 48)   18480       fire6/concat[0][0]
# __________________________________________________________________________________________________
# fire7/relu_squeeze1x1 (Activati (None, 31, 31, 48)   0           fire7/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand1x1 (Conv2D)        (None, 31, 31, 192)  9408        fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand3x3 (Conv2D)        (None, 31, 31, 192)  83136       fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand1x1 (Activatio (None, 31, 31, 192)  0           fire7/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand3x3 (Activatio (None, 31, 31, 192)  0           fire7/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/concat (Concatenate)      (None, 31, 31, 384)  0           fire7/relu_expand1x1[0][0]
#                                                                  fire7/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/squeeze1x1 (Conv2D)       (None, 31, 31, 64)   24640       fire7/concat[0][0]
# __________________________________________________________________________________________________
# fire8/relu_squeeze1x1 (Activati (None, 31, 31, 64)   0           fire8/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand1x1 (Conv2D)        (None, 31, 31, 256)  16640       fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand3x3 (Conv2D)        (None, 31, 31, 256)  147712      fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand1x1 (Activatio (None, 31, 31, 256)  0           fire8/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand3x3 (Activatio (None, 31, 31, 256)  0           fire8/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/concat (Concatenate)      (None, 31, 31, 512)  0           fire8/relu_expand1x1[0][0]
#                                                                  fire8/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/squeeze1x1 (Conv2D)       (None, 31, 31, 64)   32832       fire8/concat[0][0]
# __________________________________________________________________________________________________
# fire9/relu_squeeze1x1 (Activati (None, 31, 31, 64)   0           fire9/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand1x1 (Conv2D)        (None, 31, 31, 256)  16640       fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand3x3 (Conv2D)        (None, 31, 31, 256)  147712      fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand1x1 (Activatio (None, 31, 31, 256)  0           fire9/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand3x3 (Activatio (None, 31, 31, 256)  0           fire9/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/concat (Concatenate)      (None, 31, 31, 512)  0           fire9/relu_expand1x1[0][0]
#                                                                  fire9/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 31, 31, 512)  0           fire9/concat[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 31, 31, 512)  0           fire9/concat[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 31, 31, 512)  0           fire9/concat[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 31, 31, 3)    1539        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 31, 31, 3)    1539        dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 31, 31, 3)    1539        dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 31, 31, 3)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 31, 31, 3)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 31, 31, 3)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 3)            0           activation_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 3)            0           activation_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 3)            0           activation_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 3)            0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 3)            0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 3)            0           global_average_pooling2d_3[0][0]
# ==================================================================================================
# Total params: 727,113
# Trainable params: 727,113
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit_generator(
    train_datagen,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=val_datagen,
    validation_steps=nb_validation_samples // batch_size,
    callbacks=[checkpoint, tensorboard])
# Out:
# Epoch 1/100
# 3707/3707 [==============================] - 7330s 2s/step - loss: 3.1766 - activation_2_loss: 1.0563 - activation_4_loss: 1.0563 - activation_6_loss: 1.0640 - activation_2_acc: 0.4751 - activation_4_acc: 0.4751 - activation_6_acc: 0.4613 - val_loss: 3.1729 - val_activation_2_loss: 1.0573 - val_activation_4_loss: 1.0568 - val_activation_6_loss: 1.0589 - val_activation_2_acc: 0.4733 - val_activation_4_acc: 0.4733 - val_activation_6_acc: 0.4698
#
# Epoch 00001: saving model to C:\Users\hoang\WorkingSpace\TrainingModels\keras\checkpoints\model_squeezenet_view-offset-altitude_01.hdf5
# Epoch 2/100
# 3707/3707 [==============================] - 6952s 2s/step - loss: 3.1755 - activation_2_loss: 1.0559 - activation_4_loss: 1.0559 - activation_6_loss: 1.0637 - activation_2_acc: 0.4751 - activation_4_acc: 0.4753 - activation_6_acc: 0.4614 - val_loss: 3.1733 - val_activation_2_loss: 1.0568 - val_activation_4_loss: 1.0569 - val_activation_6_loss: 1.0595 - val_activation_2_acc: 0.4733 - val_activation_4_acc: 0.4733 - val_activation_6_acc: 0.4698
#
# Epoch 00002: saving model to C:\Users\hoang\WorkingSpace\TrainingModels\keras\checkpoints\model_squeezenet_view-offset-altitude_02.hdf5
# Epoch 3/100
# 3707/3707 [==============================] - 7294s 2s/step - loss: 3.1753 - activation_2_loss: 1.0559 - activation_4_loss: 1.0558 - activation_6_loss: 1.0636 - activation_2_acc: 0.4752 - activation_4_acc: 0.4752 - activation_6_acc: 0.4614 - val_loss: 3.1739 - val_activation_2_loss: 1.0570 - val_activation_4_loss: 1.0579 - val_activation_6_loss: 1.0589 - val_activation_2_acc: 0.4733 - val_activation_4_acc: 0.4733 - val_activation_6_acc: 0.4698
#
# Epoch 00003: saving model to C:\Users\hoang\WorkingSpace\TrainingModels\keras\checkpoints\model_squeezenet_view-offset-altitude_03.hdf5
# Epoch 4/100
# 3707/3707 [==============================] - 7600s 2s/step - loss: 3.1754 - activation_2_loss: 1.0560 - activation_4_loss: 1.0559 - activation_6_loss: 1.0635 - activation_2_acc: 0.4750 - activation_4_acc: 0.4752 - activation_6_acc: 0.4614 - val_loss: 3.1727 - val_activation_2_loss: 1.0568 - val_activation_4_loss: 1.0570 - val_activation_6_loss: 1.0589 - val_activation_2_acc: 0.4733 - val_activation_4_acc: 0.4733 - val_activation_6_acc: 0.4698
#
# Epoch 00004: saving model to C:\Users\hoang\WorkingSpace\TrainingModels\keras\checkpoints\model_squeezenet_view-offset-altitude_04.hdf5
# Epoch 5/100
# 3707/3707 [==============================] - 7983s 2s/step - loss: 3.1751 - activation_2_loss: 1.0558 - activation_4_loss: 1.0559 - activation_6_loss: 1.0634 - activation_2_acc: 0.4751 - activation_4_acc: 0.4752 - activation_6_acc: 0.4614 - val_loss: 3.1721 - val_activation_2_loss: 1.0569 - val_activation_4_loss: 1.0569 - val_activation_6_loss: 1.0584 - val_activation_2_acc: 0.4733 - val_activation_4_acc: 0.4733 - val_activation_6_acc: 0.4698
#
# Epoch 00005: saving model to C:\Users\hoang\WorkingSpace\TrainingModels\keras\checkpoints\model_squeezenet_view-offset-altitude_05.hdf5
# Epoch 6/100
# 3707/3707 [==============================] - 8011s 2s/step - loss: 3.1752 - activation_2_loss: 1.0558 - activation_4_loss: 1.0558 - activation_6_loss: 1.0635 - activation_2_acc: 0.4753 - activation_4_acc: 0.4752 - activation_6_acc: 0.4613 - val_loss: 3.1736 - val_activation_2_loss: 1.0570 - val_activation_4_loss: 1.0569 - val_activation_6_loss: 1.0596 - val_activation_2_acc: 0.4733 - val_activation_4_acc: 0.4733 - val_activation_6_acc: 0.4698
#
# Epoch 00006: saving model to C:\Users\hoang\WorkingSpace\TrainingModels\keras\checkpoints\model_squeezenet_view-offset-altitude_06.hdf5
# Epoch 7/100
# 3707/3707 [==============================] - 6946s 2s/step - loss: 3.1752 - activation_2_loss: 1.0560 - activation_4_loss: 1.0558 - activation_6_loss: 1.0634 - activation_2_acc: 0.4749 - activation_4_acc: 0.4752 - activation_6_acc: 0.4614 - val_loss: 3.1720 - val_activation_2_loss: 1.0568 - val_activation_4_loss: 1.0568 - val_activation_6_loss: 1.0583 - val_activation_2_acc: 0.4733 - val_activation_4_acc: 0.4733 - val_activation_6_acc: 0.4698
#
# Epoch 00007: saving model to C:\Users\hoang\WorkingSpace\TrainingModels\keras\checkpoints\model_squeezenet_view-offset-altitude_07.hdf5
# Epoch 8/100
#  486/3707 [==>...........................] - ETA: 1:50:19 - loss: 3.1786 - activation_2_loss: 1.0574 - activation_4_loss: 1.0556 - activation_6_loss: 1.0656 - activation_2_acc: 0.4727 - activation_4_acc: 0.4755 - activation_6_acc: 0.4571
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c18ef202d1be> in <module>()
#       5     validation_data=val_datagen,
#       6     validation_steps=nb_validation_samples // batch_size,
# ----> 7     callbacks=[checkpoint, tensorboard])
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1413             use_multiprocessing=use_multiprocessing,
#    1414             shuffle=shuffle,
# -> 1415             initial_epoch=initial_epoch)
#    1416
#    1417     @interfaces.legacy_generator_methods_support
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     175             batch_index = 0
#     176             while steps_done < steps_per_epoch:
# --> 177                 generator_output = next(output_generator)
#     178
#     179                 if not hasattr(generator_output, '__len__'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\data_utils.py in get(self)
#     576         try:
#     577             while self.is_running():
# --> 578                 inputs = self.queue.get(block=True).get()
#     579                 self.queue.task_done()
#     580                 if inputs is not None:
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# C:\ProgramData\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# C:\ProgramData\Anaconda3\lib\threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# C:\ProgramData\Anaconda3\lib\threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## continue training if necessary

# %%
# from keras.models import load_model
# model_file = 'model-uav-view_offset_altitude-normal-newlossfunction-41.hdf5'
# model_full_path = os.path.join(checkpoint_dir, model_file)
# model = load_model(model_full_path)

# file="model-uav-view_offset_altitude-normal-newlossfunction-moredata-{epoch:02d}.hdf5"
# checkpoint =  ModelCheckpoint(os.path.join(checkpoint_dir, file), verbose=1)

# model.fit_generator(
#     train_datagen,
#     steps_per_epoch=nb_train_samples // batch_size,
#     epochs=epochs,
#     validation_data=val_datagen,
#     validation_steps=nb_validation_samples // batch_size,
#     callbacks=[checkpoint])
