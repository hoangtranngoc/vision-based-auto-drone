# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras import backend as K
import numpy as np
import os
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

import sys
if "E:\\git\\keras-resnet" not in sys.path:
    sys.path.append("E:\\git\\keras-resnet")
    print(sys.path)
    
import resnet

config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.6
config.gpu_options.allow_growth = True  #dynamically grow the memory used on the GPU
set_session(tf.Session(config=config))

# dimensions of our images.
img_width, img_height = 512, 512

train_data_dir = 'E:\\UAV_drone\\data\\2019-01-04-6groups_120fov_height_normal\\train'
validation_data_dir = 'E:\\UAV_drone\\data\\2019-01-04-6groups_120fov_height_normal\\val'
nb_train_samples = 12620
nb_validation_samples = 4642
epochs = 50
batch_size = 16
img_channels = 3
nb_classes = 3

if K.image_data_format() == 'channels_first':
    input_shape = (img_channels, img_width, img_height)
else:
    input_shape = (img_width, img_height, img_channels)

model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_width, img_height), nb_classes)


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(rescale=1. / 255)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(512, 512),
    batch_size=batch_size,
    classes=['low', 'medium', 'high'])

label_map = (train_generator.class_indices)
print(label_map)

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(512, 512),
    batch_size=batch_size,
    classes=['low', 'medium', 'high'])


# checkpoint
current_directory = os.getcwd()

checkpoint_dir = os.path.join(current_directory, 'checkpoint')
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

file="model-uav-height-{epoch:02d}.hdf5"
checkpoint =  ModelCheckpoint(os.path.join(checkpoint_dir, file), verbose=1)

model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size,
    callbacks=[checkpoint])
# Out:
# Using TensorFlow backend.
# ['', 'C:\\ProgramData\\Anaconda3\\python36.zip', 'C:\\ProgramData\\Anaconda3\\DLLs', 'C:\\ProgramData\\Anaconda3\\lib', 'C:\\ProgramData\\Anaconda3', 'C:\\Users\\hoang\\AppData\\Roaming\\Python\\Python36\\site-packages', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\hoang\\.ipython', 'E:\\git\\keras-resnet']
# Found 12620 images belonging to 3 classes.
# {'low': 0, 'medium': 1, 'high': 2}
# Found 4642 images belonging to 3 classes.
# Epoch 1/50
# 788/788 [==============================] - 335s 425ms/step - loss: 1.4180 - acc: 0.3440 - val_loss: 1.2000 - val_acc: 0.3325
#
# Epoch 00001: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-01.hdf5
# Epoch 2/50
# 788/788 [==============================] - 287s 364ms/step - loss: 1.1637 - acc: 0.3368 - val_loss: 1.1286 - val_acc: 0.3348
#
# Epoch 00002: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-02.hdf5
# Epoch 3/50
# 788/788 [==============================] - 286s 363ms/step - loss: 1.1359 - acc: 0.3312 - val_loss: 1.1494 - val_acc: 0.3351
#
# Epoch 00003: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-03.hdf5
# Epoch 4/50
# 788/788 [==============================] - 283s 360ms/step - loss: 1.1224 - acc: 0.3372 - val_loss: 1.4666 - val_acc: 0.3342
#
# Epoch 00004: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-04.hdf5
# Epoch 5/50
# 788/788 [==============================] - 285s 361ms/step - loss: 1.1228 - acc: 0.3362 - val_loss: 7.2651 - val_acc: 0.3340
#
# Epoch 00005: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-05.hdf5
# Epoch 6/50
# 788/788 [==============================] - 283s 359ms/step - loss: 1.1216 - acc: 0.3213 - val_loss: 1.1701 - val_acc: 0.3327
#
# Epoch 00006: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-06.hdf5
# Epoch 7/50
# 788/788 [==============================] - 284s 361ms/step - loss: 1.1242 - acc: 0.3302 - val_loss: 1.1386 - val_acc: 0.3266
#
# Epoch 00007: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-07.hdf5
# Epoch 8/50
# 788/788 [==============================] - 283s 360ms/step - loss: 1.0909 - acc: 0.3771 - val_loss: 1.3919 - val_acc: 0.3342
#
# Epoch 00008: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-08.hdf5
# Epoch 9/50
# 788/788 [==============================] - 284s 361ms/step - loss: 0.4915 - acc: 0.8591 - val_loss: 6.7421 - val_acc: 0.4142
#
# Epoch 00009: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-09.hdf5
# Epoch 10/50
# 788/788 [==============================] - 286s 363ms/step - loss: 0.3464 - acc: 0.9084 - val_loss: 0.6680 - val_acc: 0.8039
#
# Epoch 00010: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-10.hdf5
# Epoch 11/50
# 788/788 [==============================] - 286s 363ms/step - loss: 0.2965 - acc: 0.9267 - val_loss: 0.4001 - val_acc: 0.8787
#
# Epoch 00011: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-11.hdf5
# Epoch 12/50
# 788/788 [==============================] - 284s 361ms/step - loss: 0.2478 - acc: 0.9433 - val_loss: 0.6845 - val_acc: 0.8526
#
# Epoch 00012: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-12.hdf5
# Epoch 13/50
# 788/788 [==============================] - 286s 363ms/step - loss: 0.2369 - acc: 0.9472 - val_loss: 0.3959 - val_acc: 0.8895
#
# Epoch 00013: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-13.hdf5
# Epoch 14/50
# 788/788 [==============================] - 284s 360ms/step - loss: 0.2119 - acc: 0.9548 - val_loss: 0.3822 - val_acc: 0.8971
#
# Epoch 00014: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-14.hdf5
# Epoch 15/50
# 788/788 [==============================] - 282s 357ms/step - loss: 0.2269 - acc: 0.9491 - val_loss: 0.8869 - val_acc: 0.6085
#
# Epoch 00015: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-15.hdf5
# Epoch 16/50
# 788/788 [==============================] - 282s 358ms/step - loss: 0.1962 - acc: 0.9596 - val_loss: 0.2374 - val_acc: 0.9460
#
# Epoch 00016: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-16.hdf5
# Epoch 17/50
# 788/788 [==============================] - 282s 358ms/step - loss: 0.1957 - acc: 0.9589 - val_loss: 0.9894 - val_acc: 0.6526
#
# Epoch 00017: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-17.hdf5
# Epoch 18/50
# 788/788 [==============================] - 281s 357ms/step - loss: 0.1842 - acc: 0.9616 - val_loss: 0.5978 - val_acc: 0.8675
#
# Epoch 00018: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-18.hdf5
# Epoch 19/50
# 788/788 [==============================] - 282s 357ms/step - loss: 0.1831 - acc: 0.9625 - val_loss: 0.3354 - val_acc: 0.9239
#
# Epoch 00019: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-19.hdf5
# Epoch 20/50
# 788/788 [==============================] - 281s 357ms/step - loss: 0.1653 - acc: 0.9644 - val_loss: 1.1942 - val_acc: 0.5255
#
# Epoch 00020: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-20.hdf5
# Epoch 21/50
# 788/788 [==============================] - 281s 357ms/step - loss: 0.1654 - acc: 0.9659 - val_loss: 0.5666 - val_acc: 0.8253
#
# Epoch 00021: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-21.hdf5
# Epoch 22/50
# 788/788 [==============================] - 281s 357ms/step - loss: 0.1554 - acc: 0.9668 - val_loss: 0.2244 - val_acc: 0.9479
#
# Epoch 00022: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-22.hdf5
# Epoch 23/50
# 788/788 [==============================] - 281s 357ms/step - loss: 0.1548 - acc: 0.9668 - val_loss: 0.3001 - val_acc: 0.9360
#
# Epoch 00023: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-23.hdf5
# Epoch 24/50
# 788/788 [==============================] - 283s 359ms/step - loss: 0.1492 - acc: 0.9709 - val_loss: 1.4386 - val_acc: 0.7017
#
# Epoch 00024: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-24.hdf5
# Epoch 25/50
# 788/788 [==============================] - 283s 359ms/step - loss: 0.1444 - acc: 0.9709 - val_loss: 0.3634 - val_acc: 0.9155
#
# Epoch 00025: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-25.hdf5
# Epoch 26/50
# 788/788 [==============================] - 283s 359ms/step - loss: 0.1486 - acc: 0.9699 - val_loss: 0.2810 - val_acc: 0.9440
#
# Epoch 00026: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-26.hdf5
# Epoch 27/50
# 788/788 [==============================] - 281s 356ms/step - loss: 0.1311 - acc: 0.9746 - val_loss: 0.8102 - val_acc: 0.8686
#
# Epoch 00027: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-27.hdf5
# Epoch 28/50
# 788/788 [==============================] - 282s 358ms/step - loss: 0.1248 - acc: 0.9760 - val_loss: 0.3060 - val_acc: 0.9105
#
# Epoch 00028: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-28.hdf5
# Epoch 29/50
# 788/788 [==============================] - 281s 357ms/step - loss: 0.1224 - acc: 0.9778 - val_loss: 0.2358 - val_acc: 0.9449
#
# Epoch 00029: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-29.hdf5
# Epoch 30/50
# 788/788 [==============================] - 282s 358ms/step - loss: 0.1249 - acc: 0.9778 - val_loss: 0.2556 - val_acc: 0.9410
#
# Epoch 00030: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-30.hdf5
# Epoch 31/50
# 788/788 [==============================] - 281s 357ms/step - loss: 0.1224 - acc: 0.9758 - val_loss: 0.5155 - val_acc: 0.7601
#
# Epoch 00031: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-31.hdf5
# Epoch 32/50
# 788/788 [==============================] - 280s 356ms/step - loss: 0.1136 - acc: 0.9770 - val_loss: 0.2688 - val_acc: 0.9233
#
# Epoch 00032: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-32.hdf5
# Epoch 33/50
# 788/788 [==============================] - 280s 356ms/step - loss: 0.1183 - acc: 0.9765 - val_loss: 0.1737 - val_acc: 0.9585
#
# Epoch 00033: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-33.hdf5
# Epoch 34/50
# 788/788 [==============================] - 282s 358ms/step - loss: 0.1024 - acc: 0.9814 - val_loss: 0.1699 - val_acc: 0.9633
#
# Epoch 00034: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-34.hdf5
# Epoch 35/50
# 788/788 [==============================] - 282s 358ms/step - loss: 0.1107 - acc: 0.9775 - val_loss: 0.1671 - val_acc: 0.9609
#
# Epoch 00035: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-35.hdf5
# Epoch 36/50
# 788/788 [==============================] - 281s 356ms/step - loss: 0.1008 - acc: 0.9796 - val_loss: 0.2561 - val_acc: 0.9339
#
# Epoch 00036: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-36.hdf5
# Epoch 37/50
# 788/788 [==============================] - 282s 358ms/step - loss: 0.1009 - acc: 0.9816 - val_loss: 0.7289 - val_acc: 0.8160
#
# Epoch 00037: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-37.hdf5
# Epoch 38/50
# 788/788 [==============================] - 280s 356ms/step - loss: 0.0993 - acc: 0.9803 - val_loss: 0.2463 - val_acc: 0.9393
#
# Epoch 00038: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-38.hdf5
# Epoch 39/50
# 788/788 [==============================] - 280s 356ms/step - loss: 0.1010 - acc: 0.9797 - val_loss: 0.2802 - val_acc: 0.9278
#
# Epoch 00039: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-39.hdf5
# Epoch 40/50
# 788/788 [==============================] - 282s 358ms/step - loss: 0.0965 - acc: 0.9815 - val_loss: 0.3058 - val_acc: 0.9153
#
# Epoch 00040: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-40.hdf5
# Epoch 41/50
# 788/788 [==============================] - 282s 357ms/step - loss: 0.1033 - acc: 0.9819 - val_loss: 0.2571 - val_acc: 0.9334
#
# Epoch 00041: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-41.hdf5
# Epoch 42/50
# 788/788 [==============================] - 280s 355ms/step - loss: 0.0860 - acc: 0.9858 - val_loss: 0.9903 - val_acc: 0.8374
#
# Epoch 00042: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-42.hdf5
# Epoch 43/50
# 788/788 [==============================] - 281s 357ms/step - loss: 0.0841 - acc: 0.9843 - val_loss: 3.5249 - val_acc: 0.6530
#
# Epoch 00043: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-43.hdf5
# Epoch 44/50
# 788/788 [==============================] - 281s 357ms/step - loss: 0.0858 - acc: 0.9851 - val_loss: 0.1303 - val_acc: 0.9645
#
# Epoch 00044: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-44.hdf5
# Epoch 45/50
# 788/788 [==============================] - 279s 354ms/step - loss: 0.0873 - acc: 0.9843 - val_loss: 0.1862 - val_acc: 0.9628
#
# Epoch 00045: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-45.hdf5
# Epoch 46/50
# 788/788 [==============================] - 281s 356ms/step - loss: 0.0870 - acc: 0.9841 - val_loss: 0.2998 - val_acc: 0.9001
#
# Epoch 00046: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-46.hdf5
# Epoch 47/50
# 788/788 [==============================] - 279s 354ms/step - loss: 0.0847 - acc: 0.9851 - val_loss: 0.2137 - val_acc: 0.9330
#
# Epoch 00047: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-47.hdf5
# Epoch 48/50
# 788/788 [==============================] - 281s 356ms/step - loss: 0.0803 - acc: 0.9854 - val_loss: 0.2346 - val_acc: 0.9192
#
# Epoch 00048: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-48.hdf5
# Epoch 49/50
# 788/788 [==============================] - 279s 354ms/step - loss: 0.0891 - acc: 0.9831 - val_loss: 0.6017 - val_acc: 0.8532
#
# Epoch 00049: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-49.hdf5
# Epoch 50/50
# 788/788 [==============================] - 279s 354ms/step - loss: 0.0806 - acc: 0.9857 - val_loss: 0.2231 - val_acc: 0.9477
#
# Epoch 00050: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-50.hdf5

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras import backend as K
import numpy as np
import os
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

import sys
if "E:\\git\\keras-resnet" not in sys.path:
    sys.path.append("E:\\git\\keras-resnet")
    print(sys.path)
    
import resnet

config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.6
config.gpu_options.allow_growth = True  #dynamically grow the memory used on the GPU
set_session(tf.Session(config=config))

# dimensions of our images.
img_width, img_height = 512, 512

train_data_dir = 'E:\\UAV_drone\\data\\trying_height\\train'
nb_train_samples = 1679
nb_validation_samples = 419
epochs = 50
batch_size = 8
img_channels = 3
nb_classes = 3

if K.image_data_format() == 'channels_first':
    input_shape = (img_channels, img_width, img_height)
else:
    input_shape = (img_width, img_height, img_channels)

model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_width, img_height), nb_classes)


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(rescale=1. / 255,
    validation_split=0.2)

# this is the augmentation configuration we will use for testing:
# only rescaling
#test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(512, 512),
    batch_size=batch_size,
    classes=['low', 'medium', 'high'],
    subset='training')

label_map = (train_generator.class_indices)
print(label_map)

validation_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(512, 512),
    batch_size=batch_size,
    classes=['low', 'medium', 'high'],
    subset='validation')


# checkpoint
current_directory = os.getcwd()
checkpoint_dir = os.path.join(current_directory, 'checkpoint')
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

file="model-uav-height-{epoch:02d}.hdf5"
checkpoint =  ModelCheckpoint(os.path.join(checkpoint_dir, file), verbose=1)

model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size,
    callbacks=[checkpoint])
# Out:
# Found 1679 images belonging to 3 classes.
# {'low': 0, 'medium': 1, 'high': 2}
# Found 417 images belonging to 3 classes.
# Epoch 1/50
# 209/209 [==============================] - 86s 411ms/step - loss: 1.8212 - acc: 0.3499 - val_loss: 1.5944 - val_acc: 0.3750
#
# Epoch 00001: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-01.hdf5
# Epoch 2/50
# 209/209 [==============================] - 71s 340ms/step - loss: 1.0742 - acc: 0.6777 - val_loss: 1.7432 - val_acc: 0.3350
#
# Epoch 00002: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-02.hdf5
# Epoch 3/50
# 209/209 [==============================] - 70s 334ms/step - loss: 0.7011 - acc: 0.8510 - val_loss: 1.8354 - val_acc: 0.3496
#
# Epoch 00003: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-03.hdf5
# Epoch 4/50
# 209/209 [==============================] - 69s 332ms/step - loss: 0.5953 - acc: 0.8929 - val_loss: 6.8159 - val_acc: 0.3496
#
# Epoch 00004: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-04.hdf5
# Epoch 5/50
# 209/209 [==============================] - 67s 322ms/step - loss: 0.4770 - acc: 0.9132 - val_loss: 1.0408 - val_acc: 0.6553
#
# Epoch 00005: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-05.hdf5
# Epoch 6/50
# 209/209 [==============================] - 66s 317ms/step - loss: 0.4657 - acc: 0.9131 - val_loss: 1.0092 - val_acc: 0.6406
#
# Epoch 00006: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-06.hdf5
# Epoch 7/50
# 209/209 [==============================] - 64s 306ms/step - loss: 0.4453 - acc: 0.9217 - val_loss: 1.2386 - val_acc: 0.5868
#
# Epoch 00007: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-07.hdf5
# Epoch 8/50
# 209/209 [==============================] - 65s 310ms/step - loss: 0.3417 - acc: 0.9376 - val_loss: 1.6227 - val_acc: 0.5599
#
# Epoch 00008: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-08.hdf5
# Epoch 9/50
# 209/209 [==============================] - 69s 329ms/step - loss: 0.4232 - acc: 0.9269 - val_loss: 1.5443 - val_acc: 0.3301
#
# Epoch 00009: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-09.hdf5
# Epoch 10/50
# 209/209 [==============================] - 72s 344ms/step - loss: 0.3588 - acc: 0.9408 - val_loss: 2.4961 - val_acc: 0.4083
#
# Epoch 00010: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-10.hdf5
# Epoch 11/50
# 209/209 [==============================] - 72s 343ms/step - loss: 0.3607 - acc: 0.9414 - val_loss: 1.7268 - val_acc: 0.4890
#
# Epoch 00011: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-11.hdf5
# Epoch 12/50
# 209/209 [==============================] - 69s 330ms/step - loss: 0.3149 - acc: 0.9450 - val_loss: 1.7642 - val_acc: 0.4817
#
# Epoch 00012: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-12.hdf5
# Epoch 13/50
# 209/209 [==============================] - 72s 344ms/step - loss: 0.3561 - acc: 0.9480 - val_loss: 1.8970 - val_acc: 0.3350
#
# Epoch 00013: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-13.hdf5
# Epoch 14/50
# 209/209 [==============================] - 75s 359ms/step - loss: 0.3716 - acc: 0.9354 - val_loss: 1.1751 - val_acc: 0.3961
#
# Epoch 00014: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-14.hdf5
# Epoch 15/50
# 209/209 [==============================] - 76s 362ms/step - loss: 0.2770 - acc: 0.9617 - val_loss: 2.8537 - val_acc: 0.4743
#
# Epoch 00015: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-15.hdf5
# Epoch 16/50
# 209/209 [==============================] - 76s 364ms/step - loss: 0.2974 - acc: 0.9539 - val_loss: 1.3614 - val_acc: 0.4377
#
# Epoch 00016: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-16.hdf5
# Epoch 17/50
# 209/209 [==============================] - 68s 324ms/step - loss: 0.3198 - acc: 0.9468 - val_loss: 2.2648 - val_acc: 0.3594
#
# Epoch 00017: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-17.hdf5
# Epoch 18/50
# 209/209 [==============================] - 61s 294ms/step - loss: 0.2726 - acc: 0.9480 - val_loss: 1.1128 - val_acc: 0.5550
#
# Epoch 00018: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-18.hdf5
# Epoch 19/50
# 209/209 [==============================] - 63s 303ms/step - loss: 0.2408 - acc: 0.9658 - val_loss: 2.0062 - val_acc: 0.4963
#
# Epoch 00019: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-19.hdf5
# Epoch 20/50
# 209/209 [==============================] - 62s 299ms/step - loss: 0.2480 - acc: 0.9653 - val_loss: 0.9512 - val_acc: 0.7531
#
# Epoch 00020: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-20.hdf5
# Epoch 21/50
# 209/209 [==============================] - 66s 316ms/step - loss: 0.2816 - acc: 0.9522 - val_loss: 0.6640 - val_acc: 0.8142
#
# Epoch 00021: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-21.hdf5
# Epoch 22/50
# 209/209 [==============================] - 67s 322ms/step - loss: 0.2444 - acc: 0.9634 - val_loss: 0.6292 - val_acc: 0.8215
#
# Epoch 00022: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-22.hdf5
# Epoch 23/50
# 209/209 [==============================] - 67s 319ms/step - loss: 0.2307 - acc: 0.9611 - val_loss: 0.8153 - val_acc: 0.8117
#
# Epoch 00023: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-23.hdf5
# Epoch 24/50
# 209/209 [==============================] - 68s 325ms/step - loss: 0.1932 - acc: 0.9718 - val_loss: 1.0533 - val_acc: 0.6601
#
# Epoch 00024: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-24.hdf5
# Epoch 25/50
# 209/209 [==============================] - 69s 330ms/step - loss: 0.1957 - acc: 0.9701 - val_loss: 1.8399 - val_acc: 0.6015
#
# Epoch 00025: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-25.hdf5
# Epoch 26/50
# 209/209 [==============================] - 68s 326ms/step - loss: 0.2011 - acc: 0.9707 - val_loss: 6.0239 - val_acc: 0.3350
#
# Epoch 00026: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-26.hdf5
# Epoch 27/50
# 209/209 [==============================] - 67s 320ms/step - loss: 0.2469 - acc: 0.9568 - val_loss: 1.1660 - val_acc: 0.6161
#
# Epoch 00027: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-27.hdf5
# Epoch 28/50
# 209/209 [==============================] - 65s 311ms/step - loss: 0.2296 - acc: 0.9640 - val_loss: 0.5614 - val_acc: 0.8509
#
# Epoch 00028: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-28.hdf5
# Epoch 29/50
# 209/209 [==============================] - 64s 307ms/step - loss: 0.2036 - acc: 0.9742 - val_loss: 3.5107 - val_acc: 0.4377
#
# Epoch 00029: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-29.hdf5
# Epoch 30/50
# 209/209 [==============================] - 55s 265ms/step - loss: 0.2478 - acc: 0.9557 - val_loss: 2.5147 - val_acc: 0.3936
#
# Epoch 00030: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-30.hdf5
# Epoch 31/50
# 209/209 [==============================] - 54s 257ms/step - loss: 0.2922 - acc: 0.9659 - val_loss: 9.4720 - val_acc: 0.3472
#
# Epoch 00031: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-31.hdf5
# Epoch 32/50
# 209/209 [==============================] - 51s 244ms/step - loss: 0.3283 - acc: 0.9480 - val_loss: 0.7175 - val_acc: 0.7751
# Epoch 00032: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-32.hdf5
# Epoch 33/50
# 209/209 [==============================] - 53s 252ms/step - loss: 0.2166 - acc: 0.9617 - val_loss: 3.3398 - val_acc: 0.3765
#
# Epoch 00033: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-33.hdf5
# Epoch 34/50
# 209/209 [==============================] - 54s 258ms/step - loss: 0.1992 - acc: 0.9725 - val_loss: 1.8214 - val_acc: 0.5355
#
# Epoch 00034: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-34.hdf5
# Epoch 35/50
# 209/209 [==============================] - 51s 243ms/step - loss: 0.1818 - acc: 0.9725 - val_loss: 0.4935 - val_acc: 0.8900
#
# Epoch 00035: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-35.hdf5
# Epoch 36/50
# 209/209 [==============================] - 47s 225ms/step - loss: 0.2730 - acc: 0.9545 - val_loss: 1.4767 - val_acc: 0.4083
#
# Epoch 00036: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-36.hdf5
# Epoch 37/50
# 209/209 [==============================] - 45s 214ms/step - loss: 0.2306 - acc: 0.9629 - val_loss: 0.8003 - val_acc: 0.6626
#
# Epoch 00037: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-37.hdf5
# Epoch 38/50
# 209/209 [==============================] - 50s 240ms/step - loss: 0.2092 - acc: 0.9682 - val_loss: 0.7385 - val_acc: 0.8068
#
# Epoch 00038: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-38.hdf5
# Epoch 39/50
# 209/209 [==============================] - 66s 317ms/step - loss: 0.1761 - acc: 0.9761 - val_loss: 1.1924 - val_acc: 0.5403
#
# Epoch 00039: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-39.hdf5
# Epoch 40/50
# 209/209 [==============================] - 66s 315ms/step - loss: 0.1623 - acc: 0.9755 - val_loss: 1.4652 - val_acc: 0.6406
#
# Epoch 00040: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-40.hdf5
# Epoch 41/50
# 209/209 [==============================] - 66s 314ms/step - loss: 0.1841 - acc: 0.9653 - val_loss: 0.8362 - val_acc: 0.7751
#
# Epoch 00041: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-41.hdf5
# Epoch 42/50
# 209/209 [==============================] - 67s 321ms/step - loss: 0.1652 - acc: 0.9767 - val_loss: 1.8999 - val_acc: 0.6161
#
# Epoch 00042: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-42.hdf5
# Epoch 43/50
# 209/209 [==============================] - 68s 326ms/step - loss: 0.1343 - acc: 0.9791 - val_loss: 1.1204 - val_acc: 0.6919
#
# Epoch 00043: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-43.hdf5
# Epoch 44/50
# 209/209 [==============================] - 67s 318ms/step - loss: 0.1712 - acc: 0.9737 - val_loss: 1.9092 - val_acc: 0.6504
#
# Epoch 00044: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-44.hdf5
# Epoch 45/50
# 209/209 [==============================] - 68s 324ms/step - loss: 0.2317 - acc: 0.9587 - val_loss: 0.5149 - val_acc: 0.8875
#
# Epoch 00045: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-45.hdf5
# Epoch 46/50
# 209/209 [==============================] - 70s 337ms/step - loss: 0.1944 - acc: 0.9719 - val_loss: 1.3449 - val_acc: 0.6333
#
# Epoch 00046: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-46.hdf5
# Epoch 47/50
# 209/209 [==============================] - 72s 343ms/step - loss: 0.1676 - acc: 0.9785 - val_loss: 0.5323 - val_acc: 0.8533
#
# Epoch 00047: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-47.hdf5
# Epoch 48/50
# 209/209 [==============================] - 70s 336ms/step - loss: 0.1773 - acc: 0.9730 - val_loss: 2.8844 - val_acc: 0.4156
#
# Epoch 00048: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-48.hdf5
# Epoch 49/50
# 209/209 [==============================] - 70s 336ms/step - loss: 0.1628 - acc: 0.9761 - val_loss: 2.7947 - val_acc: 0.5868
#
# Epoch 00049: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-49.hdf5
# Epoch 50/50
# 209/209 [==============================] - 65s 313ms/step - loss: 0.1598 - acc: 0.9790 - val_loss: 0.8846 - val_acc: 0.6577
#
# Epoch 00050: saving model to C:\Users\hoang\WorkingSpace\TraningModels\keras-resnet\checkpoint\model-uav-height-50.hdf5
